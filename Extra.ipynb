# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([3,4,5,6,7,8,9,10])
y = np.array([38,49,100,71,56,93,102,69])

plt.plot(x,y, marker="x",ms = 10,mec = "red", linestyle="dashed",color="blue",linewidth="3") 
plt.show()
